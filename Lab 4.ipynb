# %% [markdown]
# # Data Cleaning
#
# By Raj Saluja (11/5/19)

# %% [markdown]
# ### Introduction
#
# In this lab I explored three datasets to see what problems they had and then I cleaned two of them based on what I found through the exploration. Though there was a minimum requirement, I cleaned these datasets as much as I possibly could to get the most practice. During this lab I analyzed datasets to find problems, corrected bad headers, deleted rows, and deleted columns in order to make my two datasets as clean as possible.

# %% [markdown]
# ### Dataset Exploration

# %%
import math as m
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
attendance = pd.read_excel('attendance.xls', encoding = "iso-8859-1")

candy = pd.read_excel('BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx', encoding = "iso-8859-1")

sales = pd.read_csv('sales.csv', encoding = "iso-8859-1")

# %% [markdown]
# Here I opened the three datasets I am going to be cleaning for this lab. If  hadn't done this I wouldn't have been able to clean the data.

# %%
attendance.head()
# Out:
#   Table 43. Average daily attendance (ADA) as a percentage of total enrollment, school day length, and school year length in public schools, by school level and state: 2007-08  \
# 0                                                NaN
# 1                                                NaN
# 2                                                  1
# 3                             United States ........
# 4                          Alabama .................
#
#                                           Unnamed: 1  Unnamed: 2  \
# 0  Total elementary, secondary, and combined elem...         NaN
# 1                       ADA as percent of enrollment         NaN
# 2                                                  2         NaN
# 3                                             93.079    0.218555
# 4                                            93.8124    1.237261
#
#                     Unnamed: 3  Unnamed: 4                   Unnamed: 5  \
# ...

# %% [markdown]
# I printed the top of the attendence data to get a feel of what the dataset it like. I see that there are some serious problems with the headers, as there are three lines of headers which is confusing the code. I also see that there are a lot of NaNs, but those are a result of the messed up headers. I also see that there are 17 columns. Finally, I see what the dataset is about based on the columns. It goes over a ton of school statistics including enrollment, average day length, average number of days, how much school there is total, etc.

# %%
attendance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 17 columns):
# Table 43. Average daily attendance (ADA) as a percentage of total enrollment, school day length, and school year length in public schools, by school level and state: 2007-08    57 non-null object
# Unnamed: 1                                                                                                                                                                       55 non-null object
# Unnamed: 2                                                                                                                                                                       52 non-null float64
# Unnamed: 3                                                                                                                                                                       54 non-null object
# ...

# %%
attendance.tail()
# Out:
#    Table 43. Average daily attendance (ADA) as a percentage of total enrollment, school day length, and school year length in public schools, by school level and state: 2007-08  \
# 63                          Wyoming .................
# 64                                   †Not applicable.
# 65    ‡Reporting standards not met (too few cases).
# 66  NOTE: Averages reflect data reported by school...
# 67  SOURCE: U.S. Department of Education, National...
#
#    Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# 63     92.353    1.154487    6.85867    0.045848        175    1.278829
# 64        NaN         NaN        NaN         NaN        NaN         NaN
# 65        NaN         NaN        NaN         NaN        NaN         NaN
# 66        NaN         NaN        NaN         NaN        NaN         NaN
# 67        NaN         NaN        NaN         NaN        NaN         NaN
#
#    Unnamed: 7  Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11  Unnamed: 12  \
# ...

# %% [markdown]
# Here I checked the tail of my dataset to make sure there weren't anymore problems, but there were. I appears as if there is a final section in which the creators of the dataset made some notes. It also appears as if the symbols "†" and "‡" appear throughout the dataset, but that isn't a problem because the are essentially fill-ins for NaNs and don't make the dataset unclean. Both of these things are problems because they will prevent certain pieces of data from being a number which prevents us from using the dataset.

# %%
attendance
# Out:
#    Table 43. Average daily attendance (ADA) as a percentage of total enrollment, school day length, and school year length in public schools, by school level and state: 2007-08  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                   1
# 3                              United States ........
# 4                           Alabama .................
# 5                           Alaska ..................
# 6                           Arizona .................
# 7                           Arkansas ................
# 8                           California ..............
# 9                                                 NaN
# 10                          Colorado ................
# 11                          Connecticut .............
# 12                          Delaware ................
# 13                          District of Columbia ....
# ...

# %% [markdown]
# Here I printed the entire dataset so I could scroll through it and make sure there were no issues in the middle, but there are. It appears that every once in a while there is a row that has no data in it.

# %%
candy.head()
# Out:
#                 Timestamp  \
# 0 2016-10-24 05:09:23.033
# 1 2016-10-24 05:09:54.798
# 2 2016-10-24 05:13:06.734
# 3 2016-10-24 05:14:17.192
# 4 2016-10-24 05:14:24.625
#
#   Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                 No               Male
# 1                                                 No               Male
# 2                                                 No             Female
# 3                                                 No               Male
# 4                                                Yes               Male
#
#   How old are you? Which country do you live in?  \
# 0               22                        Canada
# 1               45                           usa
# 2               48                            US
# 3               57                           usa
# 4               42                           USA
#
# ...

# %% [markdown]
# Here I see that there aren't any issues with the headers other than the fact that they are very long. I see that the last column of the dataset has some problems because every piece of data in that column is coming in as NaN. There are some columns that I find very confusing, particularly the ones in brackets. Neither the answers or the column names themselves make sense. I see that there are many ways data can very in every column. Things can be spelled and written differently. For example, in the country column some people wrote "USA" while other wrote "US" and "usa". In the state cokums some people wrote the full state name and some only wrote the two letter symbol. There are many other places in the data where this could take place. Finally, I can tell that this data is about a lot of things, as the coulmns feature random questions about each person along with very reasonable question like age, gender, etc.

# %%
candy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Columns: 123 entries, Timestamp to  [York Peppermint Patties] Ignore
# dtypes: datetime64[ns](1), float64(1), object(121)
# memory usage: 1.2+ MB

# %% [markdown]
# This affirmed everything I stated earlier while also tellng me that this dataset has 129 rows and 123 columns.

# %%
candy.tail()
# Out:
#                    Timestamp  \
# 1254 2016-10-29 16:53:52.516
# 1255 2016-10-30 06:53:54.735
# 1256 2016-10-30 11:06:10.827
# 1257 2016-10-30 16:07:26.539
# 1258 2016-10-30 17:06:45.660
#
#      Are you going actually going trick or treating yourself? Your gender:  \
# 1254                                                 No             Female
# 1255                                                 No               Male
# 1256                                                 No               Male
# 1257                                                 No               Male
# 1258                                                Yes             Female
#
#      How old are you? Which country do you live in?  \
# 1254               52                           USA
# 1255               33                 united states
# 1256              NaN                           NaN
# 1257               48                        canada
# 1258               44                            Us
#
# ...

# %% [markdown]
# Here I made sure there were no problems with the tail like the in the attendance data. There weren't any problems.

# %%
candy
# Out:
#                    Timestamp  \
# 0    2016-10-24 05:09:23.033
# 1    2016-10-24 05:09:54.798
# 2    2016-10-24 05:13:06.734
# 3    2016-10-24 05:14:17.192
# 4    2016-10-24 05:14:24.625
# 5    2016-10-24 05:16:43.126
# 6    2016-10-24 05:16:50.572
# 7    2016-10-24 05:16:55.324
# 8    2016-10-24 05:17:49.292
# 9    2016-10-24 05:18:51.021
# 10   2016-10-24 05:20:21.125
# 11   2016-10-24 05:21:19.858
# 12   2016-10-24 05:21:27.708
# 13   2016-10-24 05:22:12.699
# 14   2016-10-24 05:22:30.678
# 15   2016-10-24 05:24:08.316
# 16   2016-10-24 05:24:11.446
# 17   2016-10-24 05:26:18.333
# 18   2016-10-24 05:26:35.167
# 19   2016-10-24 05:27:00.491
# 20   2016-10-24 05:30:39.763
# 21   2016-10-24 05:31:48.862
# 22   2016-10-24 05:33:18.915
# 23   2016-10-24 05:33:28.488
# 24   2016-10-24 05:34:36.438
# 25   2016-10-24 05:34:37.116
# 26   2016-10-24 05:34:40.001
# 27   2016-10-24 05:35:45.940
# 28   2016-10-24 05:36:13.156
# 29   2016-10-24 05:36:44.146
# ...                      ...
# ...

# %% [markdown]
# Here I printed the whole dataset to quickly scroll through like the attendance dataset to make sure there were no rows with no data like the attendance dataset. I didn't find any rows without data, but I definatley encountered some of the problems I outlined above when I printed the head.

# %%
sales.head()
# Out:
#    Unnamed: 0              event_id        primary_act_id  \
# 0           1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1           2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2           3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3           4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4           5  55b5f67e618557929f48  91c03a34b562436efa3c
#
#        secondary_act_id   purch_party_lkup_id  \
# 0  b85143bf51323b72e53c  7dfa56dd7d5956b17587
# 1  f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 2  b85143bf51323b72e53c  6c2545703bd527a7144d
# 3  b85143bf51323b72e53c  527d6b1eaffc69ddd882
# 4  b85143bf51323b72e53c  8bd62c394a35213bdf52
#
#                                           event_name  \
# 0  Xfinity Center Mansfield Premier Parking: Flor...
# 1      Gorge Camping - dave matthews band - sept 3-7
# 2        Dodge Theatre Adams Street Parking - benise
# 3  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4                      Premier Parking - motley crue
#
# ...

# %% [markdown]
# This tells me that there is one unnamed column which features the row number. It isn't important for the rest of the data, so it can be removed later. I also see that though the rest of the columns have short names, none of them make sense given the fact that they don't provide much context. Finally, I see that there are a ton of NaNs throughout the dataset which will make it very hard to use.

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 46 columns):
# Unnamed: 0                5000 non-null int64
# event_id                  5000 non-null object
# primary_act_id            5000 non-null object
# secondary_act_id          5000 non-null object
# purch_party_lkup_id       5000 non-null object
# event_name                5000 non-null object
# primary_act_name          5000 non-null object
# secondary_act_name        1586 non-null object
# major_cat_name            5000 non-null object
# minor_cat_name            5000 non-null object
# la_event_type_cat         5000 non-null object
# event_disp_name           5000 non-null object
# ticket_text               5000 non-null object
# tickets_purchased_qty     5000 non-null int64
# trans_face_val_amt        5000 non-null float64
# delivery_type_cd          5000 non-null object
# event_date_time           5000 non-null object
# event_dt                  5000 non-null object
# ...

# %% [markdown]
# This affirms what I said earlier and also tells me that there are 46 coumns and 5000 rows.

# %%
sales.tail()
# Out:
#       Unnamed: 0              event_id        primary_act_id  \
# 4995        4996  79372bc1e7e14dfd3f82  a14232befff04be1e2f3
# 4996        4997  f3b0de6a19e2a16e4fb1  83e5715f0ed3e13e6398
# 4997        4998  7c9e2f6847a2dbe4ebff  9ea8ab40f58d18305ac8
# 4998        4999  7af1ccd9a3ec3b6cef1c  e274b5c11a2a63e00141
# 4999        5000  802f4bf8026e38c2acf2  24c326bd80bd2c8c9e17
#
#           secondary_act_id   purch_party_lkup_id  \
# 4995  b85143bf51323b72e53c  8a03312852bd2a785f2c
# 4996  b2b558b1fe3efad19edb  f032fe520e8313bef880
# 4997  b85143bf51323b72e53c  f270f4daa5c3dd61a8c5
# 4998  b85143bf51323b72e53c  55a61a5e0ceb8beee897
# 4999  b22d584a2132b33e23e0  55e6e08d4b712243944d
#
#                                              event_name  \
# 4995  Premier Parking - eric clapton - pnc bank arts...
# 4996                     Sublime With Rome / rebelution
# 4997  Premier Parking : journey with heart and cheap...
# 4998                     Premier Parking: Rascal Flatts
# ...

# %% [markdown]
# Here I made sure there were no problems with the tail like the in the attendance data. There weren't any problems.

# %%
sales
# Out:
#       Unnamed: 0              event_id        primary_act_id  \
# 0              1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1              2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2              3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3              4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4              5  55b5f67e618557929f48  91c03a34b562436efa3c
# 5              6  4f10fd8b9f550352bd56  ac4b847b3fde66f2117e
# 6              7  105ea9ee10065b54b0df  a14232befff04be1e2f3
# 7              8  593b910d17913d7101cb  91c03a34b562436efa3c
# 8              9  0fb4e7152e09a40ffedd  0efaba7ce3f0d7466b42
# 9             10  93fce8094d89e0a94aac  f6425a3223e73ea6de5a
# 10            11  402bebb1d89c4024047a  8f53c0b7cd7810a1829d
# 11            12  6adcf8b2dc8a761b22b7  094156ef72361776c8ee
# 12            13  d3c8f5fb844690fb5af6  732d4f52a3ac2b7de8ef
# 13            14  5c7d36b783905ba488f4  34ad0e9254b8f7d1cbe0
# ...

# %% [markdown]
# Here I printed the whole dataset to quickly scroll through like the attendance dataset to make sure there were no rows with no data like the attendance dataset. I didn't find any rows without data, but I found that the rows I had previously believed to have had no data actually all had some data, meaning this dataset doesn't have a ton of cleaning needed.

# %% [markdown]
# I have decided to clean the attendence and sales datasets. I chose to clean these two datasets because they both seem to have very different issues that seem like they will be more complicated and therefor more useful to practice for future projects. By doing both of them I develope two very different skills while candy is pretty similar to both. The attendance dataset has horrible issues stemming from the headers and also has some rows without data while the sales dataset has a bad column along with a lot of NaN. Though the sales dataset has these probelms it doesn't have nearly as severe problems, so I choose it because it will help me to learn how to clean every aspect of a dataset that I need to even when it is virtually clean already.

# %% [markdown]
# ### Dataset Preparation 1 (Attendence)

# %%
labels = ["Country", "E + S ADA as % enrollment 1", "E + S ADA as % enrollment 2", "E + S average hours in day 1", "E + S average hours in day 2", "E + S average days in year 1", "E + S average days in year 2", "E + S average hours in year 1", "E + S average hours in year 2", "E ADA as % enrollment 1", "E ADA as % enrollment 2", "E average hours in day 1", "E average hours in day 2","S ADA as % enrollment 1", "S ADA as % enrollment 2", "S average hours in day 1", "S average hours in day 2" ]
attendance1 = pd.read_excel('attendance.xls', encoding = "iso-8859-1",
                  header=3,
                  names=labels)
index_col=False
attendance1.head()
# Out:
#                      Country  E + S ADA as % enrollment 1  \
# 0     United States ........                    93.078962
# 1  Alabama .................                    93.812371
# 2  Alaska ..................                    89.917597
# 3  Arizona .................                    89.036961
# 4  Arkansas ................                    91.827111
#
#    E + S ADA as % enrollment 2  E + S average hours in day 1  \
# 0                     0.218555                       6.64470
# 1                     1.237261                       7.02852
# 2                     1.215976                       6.47688
# 3                     2.952601                       6.43369
# 4                     1.352924                       6.88542
#
#    E + S average hours in day 2  E + S average days in year 1  \
# 0                      0.017650                         180.0
# 1                      0.065621                         180.0
# ...

# %% [markdown]
# Here I replaced the headers to make it only one row of headers. This made it so the dataset is much easier to understand and got rid of almost all of the NaNs that were present because of the weird headers. I made this a new variable so it wouldn't impact the results I get in the dataset exploration section. On the first line I wrote the new headers. Every original header contained two columns of data, so I ended up making two headers for each piece of data to get every column filled. On the second line I had pandad read the dataset, on the third line I states that rows 0, 1, 2, and 3 were header rows that needed to be deleted, and on the fourth line I replaced the headers with the ones I wrote. I then added a piece of code that I will need in order to remove certain rows later on on line five. Finally, I printed the head of the dataset to make sure it worked, and it did. The row three (the fourth row) wasn't a header, but something that labeled each section of the dataset with a number. This was also creating some problems so I added it to the list of headers to get rid of it.

# %%
attendance1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 17 columns):
# Country                          56 non-null object
# E + S ADA as % enrollment 1      52 non-null float64
# E + S ADA as % enrollment 2      52 non-null float64
# E + S average hours in day 1     52 non-null float64
# E + S average hours in day 2     52 non-null float64
# E + S average days in year 1     52 non-null float64
# E + S average days in year 2     52 non-null float64
# E + S average hours in year 1    52 non-null float64
# E + S average hours in year 2    52 non-null float64
# E ADA as % enrollment 1          52 non-null float64
# E ADA as % enrollment 2          52 non-null float64
# E average hours in day 1         52 non-null float64
# E average hours in day 2         52 non-null float64
# S ADA as % enrollment 1          52 non-null object
# S ADA as % enrollment 2          52 non-null object
# S average hours in day 1         52 non-null object
# ...

# %% [markdown]
# Here I double-checked to make sure I got everything right by using info intead of head, and everything was right.

# %%
attendance1.drop([61], inplace=True)
attendance1.drop([62], inplace=True)
attendance1.drop([63], inplace=True)
attendance1.drop([64], inplace=True)
attendance1.tail()
# Out:
#                       Country  E + S ADA as % enrollment 1  \
# 56  Virginia ................                    94.677993
# 57  Washington ..............                    82.855625
# 58  West Virginia ...........                    94.009760
# 59  Wisconsin ...............                    94.950856
# 60  Wyoming .................                    92.353008
#
#     E + S ADA as % enrollment 2  E + S average hours in day 1  \
# 56                     0.460467                       6.61718
# 57                     3.056990                       6.22202
# 58                     0.987722                       6.87364
# 59                     0.566144                       6.91175
# 60                     1.154487                       6.85867
#
#     E + S average hours in day 2  E + S average days in year 1  \
# 56                      0.050234                         181.0
# 57                      0.080353                         179.0
# ...

# %% [markdown]
# Here I removed the last four rows of the dataset to get rid of the problems involving the tail. This way I can get rid of the NaNs that were present. I then printed the dataset to make sure it worked. It worked well.

# %%
attendance1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 0 to 60
# Data columns (total 17 columns):
# Country                          52 non-null object
# E + S ADA as % enrollment 1      52 non-null float64
# E + S ADA as % enrollment 2      52 non-null float64
# E + S average hours in day 1     52 non-null float64
# E + S average hours in day 2     52 non-null float64
# E + S average days in year 1     52 non-null float64
# E + S average days in year 2     52 non-null float64
# E + S average hours in year 1    52 non-null float64
# E + S average hours in year 2    52 non-null float64
# E ADA as % enrollment 1          52 non-null float64
# E ADA as % enrollment 2          52 non-null float64
# E average hours in day 1         52 non-null float64
# E average hours in day 2         52 non-null float64
# S ADA as % enrollment 1          52 non-null object
# S ADA as % enrollment 2          52 non-null object
# S average hours in day 1         52 non-null object
# ...

# %% [markdown]
# Here I used .info to double check and make sure everything worked right and it did.

# %%
attendance1.drop([6], inplace=True)
attendance1.drop([12], inplace=True)
attendance1.drop([18], inplace=True)
attendance1.drop([24], inplace=True)
attendance1.drop([30], inplace=True)
attendance1.drop([36], inplace=True)
attendance1.drop([42], inplace=True)
attendance1.drop([48], inplace=True)
attendance1.drop([54], inplace=True)
attendance1
# Out:
#                       Country  E + S ADA as % enrollment 1  \
# 0      United States ........                    93.078962
# 1   Alabama .................                    93.812371
# 2   Alaska ..................                    89.917597
# 3   Arizona .................                    89.036961
# 4   Arkansas ................                    91.827111
# 5   California ..............                    93.241017
# 7   Colorado ................                    93.887162
# 8   Connecticut .............                    87.925871
# 9   Delaware ................                    89.770581
# 10  District of Columbia ....                    91.220829
# 11  Florida .................                    92.678174
# 13  Georgia .................                    93.266158
# 14  Hawaii ..................                    90.721279
# 15  Idaho ...................                    92.373340
# 16  Illinois ................                    93.970461
# ...

# %% [markdown]
# Here I removed all of the rows that had no data. This got rid of all the rest of the NaNs. I then printed to make sure everything was right.

# %%
attendance1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 60
# Data columns (total 17 columns):
# Country                          52 non-null object
# E + S ADA as % enrollment 1      52 non-null float64
# E + S ADA as % enrollment 2      52 non-null float64
# E + S average hours in day 1     52 non-null float64
# E + S average hours in day 2     52 non-null float64
# E + S average days in year 1     52 non-null float64
# E + S average days in year 2     52 non-null float64
# E + S average hours in year 1    52 non-null float64
# E + S average hours in year 2    52 non-null float64
# E ADA as % enrollment 1          52 non-null float64
# E ADA as % enrollment 2          52 non-null float64
# E average hours in day 1         52 non-null float64
# E average hours in day 2         52 non-null float64
# S ADA as % enrollment 1          52 non-null object
# S ADA as % enrollment 2          52 non-null object
# S average hours in day 1         52 non-null object
# ...

# %% [markdown]
# Here I used .info to double check and make sure everything worked right and it did.

# %% [markdown]
# ### Dataset Preparation 2 (Sales)

# %%
sales1 = pd.read_csv('sales.csv', encoding = "iso-8859-1")

# %% [markdown]
# Here I created a new varible for the sales dataset so my cleaning won't affect the dataset exploration of this lab where I looked at the uncleaned datasets.

# %%
del sales1['Unnamed: 0']
sales1.head()
# Out:
#                event_id        primary_act_id      secondary_act_id  \
# 0  abcaf1adb99a935fc661  43f0436b905bfa7c2eec  b85143bf51323b72e53c
# 1  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794  f53529c5679ea6ca5a48
# 2  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1  b85143bf51323b72e53c
# 3  394cb493f893be9b9ed1  b1ccea01ad6ef8522796  b85143bf51323b72e53c
# 4  55b5f67e618557929f48  91c03a34b562436efa3c  b85143bf51323b72e53c
#
#     purch_party_lkup_id                                         event_name  \
# 0  7dfa56dd7d5956b17587  Xfinity Center Mansfield Premier Parking: Flor...
# 1  4f9e6fc637eaf7b736c2      Gorge Camping - dave matthews band - sept 3-7
# 2  6c2545703bd527a7144d        Dodge Theatre Adams Street Parking - benise
# 3  527d6b1eaffc69ddd882  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4  8bd62c394a35213bdf52                      Premier Parking - motley crue
#
#                            primary_act_name  secondary_act_name  \
# ...

# %% [markdown]
# Here I cleaned my first column of the dataset by completely removing the first column. This column just repeated the row numbers but was one off and didn't have a header, so it was best just to get rid of it to make the dataset cleaner. I then printed the head of the dataset to make sure it worked and it did.

# %%
sales1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 45 columns):
# event_id                  5000 non-null object
# primary_act_id            5000 non-null object
# secondary_act_id          5000 non-null object
# purch_party_lkup_id       5000 non-null object
# event_name                5000 non-null object
# primary_act_name          5000 non-null object
# secondary_act_name        1586 non-null object
# major_cat_name            5000 non-null object
# minor_cat_name            5000 non-null object
# la_event_type_cat         5000 non-null object
# event_disp_name           5000 non-null object
# ticket_text               5000 non-null object
# tickets_purchased_qty     5000 non-null int64
# trans_face_val_amt        5000 non-null float64
# delivery_type_cd          5000 non-null object
# event_date_time           5000 non-null object
# event_dt                  5000 non-null object
# presale_dt                2108 non-null object
# ...

# %% [markdown]
# Here I used .info to double check and make sure everything worked right and it did.

# %%
sales1.describe()
# Out:
#        tickets_purchased_qty  trans_face_val_amt      age_yr     income_amt  \
# count             5000.00000         5000.000000  168.000000     154.000000
# mean                 1.63900           77.077446   44.369048   86396.103896
# std                  1.11361          123.864788   16.531067   58895.045547
# min                  1.00000            1.000000   18.000000   10000.000000
# 25%                  1.00000           20.000000   30.000000   45000.000000
# 50%                  1.00000           30.000000   44.000000   62500.000000
# 75%                  2.00000           85.000000   56.000000   87500.000000
# max                  8.00000         1520.880000   94.000000  200000.000000
#
#        adults_in_hh_num  married_ind  child_present_ind  home_owner_ind  \
# count        176.000000   157.000000         130.000000      138.000000
# mean           2.579545     0.668790           0.561538        0.942029
# ...

# %%
del sales1['event_date_time']
sales1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 44 columns):
# event_id                  5000 non-null object
# primary_act_id            5000 non-null object
# secondary_act_id          5000 non-null object
# purch_party_lkup_id       5000 non-null object
# event_name                5000 non-null object
# primary_act_name          5000 non-null object
# secondary_act_name        1586 non-null object
# major_cat_name            5000 non-null object
# minor_cat_name            5000 non-null object
# la_event_type_cat         5000 non-null object
# event_disp_name           5000 non-null object
# ticket_text               5000 non-null object
# tickets_purchased_qty     5000 non-null int64
# trans_face_val_amt        5000 non-null float64
# delivery_type_cd          5000 non-null object
# event_dt                  5000 non-null object
# presale_dt                2108 non-null object
# onsale_dt                 4899 non-null object
# ...

# %% [markdown]
# Here I cleaned my second coulumn of data. There was a column in the middle of the dataset that contained no data whatsoever, so I deleted it because it was useless. This column was burried in the dataset, so I couldn't see it when printing the head so I just looked at the info to see if it worked, and it did because the number of columns went from 45 to 44.

# %% [markdown]
# ### Conclusion
#
# I felt as if the attendance dataset was much less clean than the sales dataset. I found that the attenance dataset didn't have many problems in the data itself, but more problems in the way it was formatted. First of all, there were three lines of headers. Second, each header contained two columns of data, and third there were many rows that had no data at all and were merely there as dividers. Finally, at the end of the dataset there was a thing of notes that needed to be gotten rid of. I feel as if I did a great job cleaning this dataset because I was able to fix all of these problems and make the dataset virtually completely clean. THe sales dataset had a lot fewer issues. The first column had a repeat of therow numbers, but it was off by one. Also, there were a lot of NaNs but those didn't make the dataset unclean they just demonstrated the fact that there was no data for the particular section. Finally, there was one column in which there was no data at all. Other than that, however, there were no issues. This was a very useable dataset even if I wasn't to clean it at all. I feel as if I did a very good job cleaning this dataset because even though it didn't have many issues I was able to fix all of the problems and make it incredibly clean.

# %% [markdown]
# ### Acknowledgements
#
# I would like to thank Ms. Sconyers and this website: https://stackoverflow.com/questions/13411544/delete-column-from-pandas-dataframe. They both helped me find code that I used to clean the datasets.
